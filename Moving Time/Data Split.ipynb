# %%
import pandas as pd
import numpy as np
import os
from tqdm import tqdm
# selenium의 webdriver를 사용하기 위한 import
from selenium import webdriver
from selenium.webdriver.common.by import By
# selenium으로 무엇인가 입력하기 위한 import
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
# 페이지 로딩을 기다리는데에 사용할 time 모듈 import
import time

cwd = os.getcwd()
print('현재 폴더 경로 : ', cwd)
# 폴더 위치 변경
os.chdir("C:\\Users\hyunj\\Dropbox\\종합설계프로젝트\\중요\\데이터\\")
print('변경 후 폴더 경로 : ', cwd)
print('현재 폴더 파일 : ', os.listdir())
data = pd.read_csv('Container perspective.csv')
print('feature 항목 : ', data.columns)
data
# Out:
# 현재 폴더 경로 :  c:\Users\hyunj\Desktop\종합설계프로젝트
# 변경 후 폴더 경로 :  c:\Users\hyunj\Desktop\종합설계프로젝트
# 현재 폴더 파일 :  ['Block perspective.csv', 'CHE I perspective.csv', 'CHE II perspective.csv', 'Container Data.csv', 'Container perspective.csv', 'Data.csv', 'DS.csv', 'DStoLD.csv', 'Dwell Time', 'Gate perspective.csv', 'GI perspective.csv', 'GO perspective.csv', 'ITV perspective.csv', 'LD.csv', 'QC perspective.csv', 'TC Data', 'TC Data.csv', 'TC224.csv', 'TC224_DS.csv', 'TC224_GI.csv', 'TC224_LD.csv', 'Vessel perspective.csv']
# feature 항목 :  Index(['Unnamed: 0', 'VESSEL', 'CONTAINER_NO', 'MCHN_ID', 'MCHN_TP_CD',
#        'FULL_EMPTY', 'JOB_TYPE', 'POD', 'BLOCK_BAY', 'JOB_START_DT',
#        'JOB_END_DT'],
#       dtype='object')
#         Unnamed: 0         VESSEL   CONTAINER_NO MCHN_ID MCHN_TP_CD  \
# 0                1  ALAP-001/2018  AXIU1484082-2   GC112         QC
# 1                2  ALAP-001/2018  AXIU1484082-2   TC221         TC
# ...

# %%
# 데이터 DS
data_ds = data[data['JOB_TYPE'].str.startswith('DS')]
data_ds.reset_index(drop=True, inplace=True)
data_ds
# Out:
#         Unnamed: 0         VESSEL   CONTAINER_NO MCHN_ID MCHN_TP_CD  \
# 0                1  ALAP-001/2018  AXIU1484082-2   GC112         QC
# 1                2  ALAP-001/2018  AXIU1484082-2   TC221         TC
# 2                3  ALAP-001/2018  AXIU1484082-2   YT511         YT
# 3                7  ALAP-001/2018  BGBU5060490-3   GC109         QC
# 4                8  ALAP-001/2018  BGBU5060490-3   TC266         TC
# ...            ...            ...            ...     ...        ...
# 223759      424301  SXNW-001/2018  UESU4153686-1   TC231         TC
# 223760      424302  SXNW-001/2018  UESU4153686-1   YT526         YT
# 223761      424303  SXNW-001/2018  UESU4586161-1   GC110         QC
# 223762      424304  SXNW-001/2018  UESU4586161-1   TC224         TC
# 223763      424305  SXNW-001/2018  UESU4586161-1   YT529         YT
#
#        FULL_EMPTY     JOB_TYPE    POD BLOCK_BAY    JOB_START_DT  \
# 0               F  DS-QUAYSIDE  KRPUS     1B-38  20180131211752
# ...

# %%
# 데이터 LD
data_ld = data[data['JOB_TYPE'].str.startswith('LD')]
data_ld.reset_index(drop=True, inplace=True)
data_ld
# Out:
#         Unnamed: 0         VESSEL   CONTAINER_NO MCHN_ID MCHN_TP_CD  \
# 0                4  ALAP-001/2018  BEAU2976719-1   GC111         GC
# 1                5  ALAP-001/2018  BEAU2976719-1   TC223         TC
# 2                6  ALAP-001/2018  BEAU2976719-1   YT511         YT
# 3               25  ALAP-001/2018  BMOU2088902-1   GC109         GC
# 4               26  ALAP-001/2018  BMOU2088902-1   TC226         TC
# ...            ...            ...            ...     ...        ...
# 200557      424322  SXNW-001/2018  XINU1481982-2   TC225         TC
# 200558      424323  SXNW-001/2018  XINU1481982-2   YT505         YT
# 200559      424324  SXNW-001/2018  YMLU3166534-1   GC111         GC
# 200560      424325  SXNW-001/2018  YMLU3166534-1   TC242         TC
# 200561      424326  SXNW-001/2018  YMLU3166534-1   YT522         YT
#
#        FULL_EMPTY     JOB_TYPE    POD BLOCK_BAY    JOB_START_DT  \
# 0               F  LD-QUAYSIDE  CAVAN     2B-19  20180131202120
# ...

# %%
# 데이터 저장
data_ds.to_csv('Container DS perspective.csv', index=False, encoding='CP949')
data_ld.to_csv('Container LD perspective.csv', index=False, encoding='CP949')
